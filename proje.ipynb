# %%
#öğrenci not bilgi sistemi
import time
import sys
derslist = ["1:YGT", "2:İstatistik", "3:lineer", "4:matematik", "5:makine", "6:bilişim"]
derssayisi = len(derslist)
EEM = []

#Login Bölümü
print("Giriş için 3 deneme hakkınız var")
i=1
while i < 4:
	adı = input("Ad:")
	soyadı = input("Soyad:")
	if adı =='seval' and soyadı=='çurku':
		print("Hoşgeldin {} {}" .format(adı, soyadı))
		break

	else:
		print('Hatalı ! tekrar deneyin.')
		print("{}. deneme" .format(i))
		i += 1
		if i == 4:
			print('3.de başarısız oldu!!')
			sys.exit(1)
   
#kaç ders seçelim
print("Listeden en az 3, en fazla 5 ders seçiniz")
print(derslist)
time.sleep(1)

#ders ekleme kısmı
i = 0
while i < 5:
	dersSec = int(input("Ders seçimini yap (1-6):"))
	if(dersSec == 1):
		if ('1:YGT' in EEM):
			print("\n *YGT dersini zaten seçmişsiniz")
			i -= 1
		else:
			EEM.append(derslist[0])
			print("\n=> {} dersi eklendi \n".format(derslist[0]))
			print(EEM)

	if (dersSec == 2):
		if ('2:İstatistik' in EEM):
			print("\n *İstatistik dersini zaten seçmişsiniz")
			i -= 1
		else:
			EEM.append(derslist[1])
			print("\n=> {} dersi eklendi \n".format(derslist[1]))
			print(EEM)

	if (dersSec == 3):
		if ('3:lineer' in EEM):
			print("\n *lineer dersini zaten seçmişsiniz")
			i -= 1
		else:
			EEM.append(derslist[2])
			print("\n=> {} dersi eklendi \n".format(derslist[2]))
			print(EEM)

	if (dersSec == 4):
		if ('4:matematik' in EEM):
			print("\n *matematik dersini zaten seçmişsiniz")
			i -= 1
		else:
			EEM.append(derslist[3])
			print("\n=> {} dersi eklendi \n".format(derslist[3]))
			print(EEM)

	if (dersSec == 5):
		if ('5:makine' in EEM):
			print("\n *makine dersini zaten seçmişsiniz")
			i -= 1
		else:
			EEM.append(derslist[4])
			print("\n=> {} dersi  eklendi \n".format(derslist[4]))
			print(EEM)

	if (dersSec == 6):
		if ('6:bilişim' in EEM):
			print("\n *bilişim dersini zaten seçmişsiniz")
			i -= 1
		else:
			EEM.append(derslist[5])
			print("\n=> {} dersi eklendi \n".format(derslist[5]))
			print(EEM)

	i += 1
	print("Toplam {} ders aldınız".format(len(EEM)))
	if i < 3:
		print("En az 3 ders seçmeniz gerekmektedir aksi takdirde kalmış sayılacaksınız")
	if  i >= 3 and \
		i< 5:
		print("5 ders seçme hakkınız var")
	if i == 5:
		print("***Tebrikler. Ders seçimini tamaladınız***")
		EEM.sort()
		print("Kayıt olduğunuz dersler {}" .format(EEM))
		print("Yukarıda, aldığınız derslerden 1 tanesinin sınavına girmek için seçiniz")
		sinavDersSecim = int(input("Sınav Ders seçiminizi yapınız (1-6):"))

		if (sinavDersSecim == 1):
			print("\n*Sınava Gireceğiniz ders YGT")

		if (sinavDersSecim == 2):
			print("\n*Sınava Gireceğiniz ders İstatistik")

		if (sinavDersSecim == 3):
			print("\n*Sınava Gireceğiniz ders lineer")

		if (sinavDersSecim == 4):
			print("\n*Sınava Gireceğiniz ders matematik")

		if (sinavDersSecim == 5):
			print("\n*Sınava Gireceğiniz ders makine")

		if (sinavDersSecim == 6):
			print("\n*Sınava Gireceğiniz ders bilişim")

print("Notlarınızı Giriniz:")

while True:
    try:
        vize = int(input('Vize: '))
    except ValueError:
        print("Rakam giriniz")
        exit(-1)
    if 0 < vize <=100:
        break
    else:
        print("Vize notu 1-100 arasında olmalıdır")

while True:
    try:
        proje = int(input('Proje: '))
    except ValueError:
        print("Rakam giriniz")
        exit(-1)
    if 0 < proje <=100:
        break
    else:
        print("Proje notu 1-100 arasında olmalıdır")

while True:
    try:
        final = int(input('Final: '))
    except ValueError:
        print("Rakam giriniz")
        exit(-1)
    if 0 < final <=100:
        break
    else:
        print("Final notu 1-100 arasında olmalı")

summ = vize * 0.3 + final * 0.5 + proje * 0.2
if 89 < summ:
	hN = "AA"
elif 69 < summ < 90:
	hN = "BB"
elif 49 < summ < 70:
	hN  = "CC"
elif 29 < summ < 50:
	hN  = "DD"
elif summ< 30:
	hN  = "FF"

print("Ders sonucunuz: ({}) {}".format(hN , round(summ, 2)))
if hN  == 'FF':
	print("Kaldınız!")
else:
	print("Tebrikler Geçtiniz.")
